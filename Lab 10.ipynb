# %% [markdown]
# # A MongoDB JSON Document Database
# - The purpose of this project is to store and search JSON for 10,000 streamed tweets about 100 U.S. senators
# - Summarize top 10 by tweet count
# - Display interactive map containing tweet count summaries
# - 10,000 tweets can take substantial time
# - Possible enhancement — Use sentiment analysis to count positive, negative and neutral tweets mentioning each senator’s handle

# %%
# enable high-res images in notebook
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ### Use Tweepy to Authenticate with Twitter and Get the API Object

# %%
import tweepy, keys

auth = tweepy.OAuthHandler(
    keys.consumer_key, keys.consumer_secret)
auth.set_access_token(keys.access_token, 
    keys.access_token_secret)

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, 
                 wait_on_rate_limit_notify=True)

# %% [markdown]
# ### Load the Senators' Data

# %%
import pandas as pd

senators_df = pd.read_csv('senators.csv')

senators_df['TwitterID'] = senators_df['TwitterID'].astype(str)

pd.options.display.max_columns = 6

senators_df.head()
# Out:
#   State            Name Party   TwitterHandle           TwitterID
# 0    AL  Richard Shelby     R       SenShelby            21111098
# 1    AL      Doug Jomes     D    SenDougJones  941080085121175552
# 2    AK  Lisa Murkowski     R   lisamurkowski            18061669
# 3    AK    Dan Sullivan     R  SenDanSullivan          2891210047
# 4    AZ  Martha McSally     R    SenMcSallyAZ          2964949642

# %% [markdown]
# ### Configuring the MongoClient

# %%
from pymongo import MongoClient

atlas_client = MongoClient(keys.mongo_connection_string)

db = atlas_client.senators

# %% [markdown]
# ### Setting up Tweet Stream

# %%
from tweetlistener import TweetListener

# %%
tweet_limit = 500

# %%
import json

class TweetListener(tweepy.StreamListener):
    """Handles incoming Tweet stream."""

    def __init__(self, api, database, limit=10000):
        """Create instance variables for tracking number of tweets."""
        self.db = database
        self.tweet_count = 0
        self.TWEET_LIMIT = limit  # 10,000 by default
        super().__init__(api)  # call superclass's init

    def on_connect(self):
        """Called when your connection attempt is successful, enabling 
        you to perform appropriate application tasks at that point."""
        print('Successfully connected to Twitter\n')

    def on_data(self, data):
        """Called when Twitter pushes a new tweet to you."""
        self.tweet_count += 1  # track number of tweets processed
        json_data = json.loads(data)  # convert string to JSON
        self.db.tweets.insert_one(json_data)  # store in tweets collection
        print(f'    Screen name: {json_data["user"]["name"]}') 
        print(f'     Created at: {json_data["created_at"]}')         
        print(f'Tweets received: {self.tweet_count}')         

        # if TWEET_LIMIT is reached, return False to terminate streaming
        return self.tweet_count != self.TWEET_LIMIT
    
    def on_error(self, status):
        print(f'Error: {status}')
        return True

# %%
twitter_stream = tweepy.Stream(api.auth, 
    TweetListener(api, db, tweet_limit))

# %%
twitter_stream.filter(track=senators_df.TwitterHandle.tolist(),
    follow=senators_df.TwitterID.tolist())
# Out:
# Successfully connected to Twitter
#
#     Screen name: 沙广白左
#      Created at: Fri Apr 09 16:03:15 +0000 2021
# Tweets received: 1
#     Screen name: scubaemt
#      Created at: Fri Apr 09 16:03:16 +0000 2021
# Tweets received: 2
#     Screen name: Roberta Eidman Has Started Prepping for 2022
#      Created at: Fri Apr 09 16:03:16 +0000 2021
# Tweets received: 3
#     Screen name: Peggy Stuart, Pragmatic Progressive
#      Created at: Fri Apr 09 16:03:16 +0000 2021
# Tweets received: 4
#     Screen name: JoeManchin’sDreamJournal
#      Created at: Fri Apr 09 16:03:16 +0000 2021
# Tweets received: 5
#     Screen name: Donna Adamski
#      Created at: Fri Apr 09 16:03:18 +0000 2021
# Tweets received: 6
#     Screen name: East Valley Indivisibles
#      Created at: Fri Apr 09 16:03:18 +0000 2021
# Tweets received: 7
#     Screen name: Maureen Copatch
#      Created at: Fri Apr 09 16:03:18 +0000 2021
# Tweets received: 8
#     Screen name: Laura rutmanis
#      Created at: Fri Apr 09 16:03:18 +0000 2021
# Tweets received: 9
#     Screen name: Debi k
#      Created at: Fri Apr 09 16:03:19 +0000 2021
# Tweets received: 10
#     Screen name: Glutton4Punishment
#      Created at: Fri Apr 09 16:03:19 +0000 2021
# Tweets received: 11
#     Screen name: crimson151
#      Created at: Fri Apr 09 16:03:21 +0000 2021
# Tweets received: 12
#     Screen name: Jamesmarks
#      Created at: Fri Apr 09 16:03:22 +0000 2021
# Tweets received: 13
#     Screen name: Bob Oliver
#      Created at: Fri Apr 09 16:03:22 +0000 2021
# Tweets received: 14
#     Screen name: Trumpfails2
#      Created at: Fri Apr 09 16:03:23 +0000 2021
# Tweets received: 15
#     Screen name: Laura rutmanis
#      Created at: Fri Apr 09 16:03:23 +0000 2021
# Tweets received: 16
#     Screen name: Flip AZ Blue
#      Created at: Fri Apr 09 16:03:23 +0000 2021
# Tweets received: 17
#     Screen name: CKCy
#      Created at: Fri Apr 09 16:03:23 +0000 2021
# Tweets received: 18
#     Screen name: HOKIEKAT
#      Created at: Fri Apr 09 16:03:23 +0000 2021
# Tweets received: 19
#     Screen name: Wayne Lockhart
#      Created at: Fri Apr 09 16:03:24 +0000 2021
# Tweets received: 20
#     Screen name: Ben Stotler
#      Created at: Fri Apr 09 16:03:24 +0000 2021
# Tweets received: 21
#     Screen name: Lyndee
#      Created at: Fri Apr 09 16:03:24 +0000 2021
# Tweets received: 22
#     Screen name: PeaceJustice⚖️
#      Created at: Fri Apr 09 16:03:24 +0000 2021
# Tweets received: 23
#     Screen name: Edward Wear a Mask Perez
#      Created at: Fri Apr 09 16:03:25 +0000 2021
# Tweets received: 24
#     Screen name: simongriot
#      Created at: Fri Apr 09 16:03:25 +0000 2021
# Tweets received: 25
#     Screen name: Maite
#      Created at: Fri Apr 09 16:03:26 +0000 2021
# Tweets received: 26
#     Screen name: Anita Thompson
#      Created at: Fri Apr 09 16:03:26 +0000 2021
# Tweets received: 27
#     Screen name: Kimberly  (Kimbob)
#      Created at: Fri Apr 09 16:03:27 +0000 2021
# Tweets received: 28
#     Screen name: BearInHK
#      Created at: Fri Apr 09 16:03:27 +0000 2021
# Tweets received: 29
#     Screen name: COOL VFX
#      Created at: Fri Apr 09 16:03:27 +0000 2021
# Tweets received: 30
#     Screen name: John J O'Donnell
#      Created at: Fri Apr 09 16:03:27 +0000 2021
# Tweets received: 31
#     Screen name: Amy W
#      Created at: Fri Apr 09 16:03:27 +0000 2021
# Tweets received: 32
#     Screen name: Edward Carl Lind lll
#      Created at: Fri Apr 09 16:03:27 +0000 2021
# Tweets received: 33
#     Screen name: carolmfarkas
#      Created at: Fri Apr 09 16:03:27 +0000 2021
# Tweets received: 34
#     Screen name: memaw
#      Created at: Fri Apr 09 16:03:28 +0000 2021
# Tweets received: 35
#     Screen name: AMCS
#      Created at: Fri Apr 09 16:03:28 +0000 2021
# Tweets received: 36
#     Screen name: Jewish Space Laser Tech for hire
#      Created at: Fri Apr 09 16:03:28 +0000 2021
# Tweets received: 37
#     Screen name: Ewindham3
#      Created at: Fri Apr 09 16:03:29 +0000 2021
# Tweets received: 38
#     Screen name: Peggy Stuart, Pragmatic Progressive
#      Created at: Fri Apr 09 16:03:29 +0000 2021
# Tweets received: 39
#     Screen name: victoria bieber
#      Created at: Fri Apr 09 16:03:29 +0000 2021
# Tweets received: 40
#     Screen name: Raymundo Perez
#      Created at: Fri Apr 09 16:03:29 +0000 2021
# Tweets received: 41
#     Screen name: Klk
#      Created at: Fri Apr 09 16:03:30 +0000 2021
# Tweets received: 42
#     Screen name: Desi
#      Created at: Fri Apr 09 16:03:32 +0000 2021
# Tweets received: 43
#     Screen name: BoneZ
#      Created at: Fri Apr 09 16:03:33 +0000 2021
# Tweets received: 44
#     Screen name: just_in_case
#      Created at: Fri Apr 09 16:03:33 +0000 2021
# Tweets received: 45
#     Screen name: loriandmax
#      Created at: Fri Apr 09 16:03:34 +0000 2021
# Tweets received: 46
#     Screen name: High Skilled Immigration
#      Created at: Fri Apr 09 16:03:34 +0000 2021
# Tweets received: 47
#     Screen name: Joey Witlouw
#      Created at: Fri Apr 09 16:03:34 +0000 2021
# Tweets received: 48
#     Screen name: Mary Hulsey
#      Created at: Fri Apr 09 16:03:34 +0000 2021
# Tweets received: 49
#     Screen name: Martin
#      Created at: Fri Apr 09 16:03:35 +0000 2021
# Tweets received: 50
#     Screen name: G Pacella
#      Created at: Fri Apr 09 16:03:35 +0000 2021
# Tweets received: 51
#     Screen name: Peggy Stuart, Pragmatic Progressive
#      Created at: Fri Apr 09 16:03:36 +0000 2021
# Tweets received: 52
#     Screen name: laurajfinn
#      Created at: Fri Apr 09 16:03:36 +0000 2021
# Tweets received: 53
#     Screen name: Aunt Tiffa 🌐✈️
#      Created at: Fri Apr 09 16:03:37 +0000 2021
# Tweets received: 54
#     Screen name: Maite
#      Created at: Fri Apr 09 16:03:38 +0000 2021
# Tweets received: 55
#     Screen name: Lady Liberty
#      Created at: Fri Apr 09 16:03:39 +0000 2021
# Tweets received: 56
#     Screen name: michael.wong
#      Created at: Fri Apr 09 16:03:39 +0000 2021
# Tweets received: 57
#     Screen name: Karen LaRiviere💙🐕🐕🐕🐕🐕💙
#      Created at: Fri Apr 09 16:03:40 +0000 2021
# Tweets received: 58
#     Screen name: Pete Wyckoff
#      Created at: Fri Apr 09 16:03:40 +0000 2021
# Tweets received: 59
#     Screen name: Ben Mattick
#      Created at: Fri Apr 09 16:03:40 +0000 2021
# Tweets received: 60
#     Screen name: Jack Kolinski
#      Created at: Fri Apr 09 16:03:41 +0000 2021
# Tweets received: 61
#     Screen name: WeRQed 🗣🗣
#      Created at: Fri Apr 09 16:03:41 +0000 2021
# Tweets received: 62
#     Screen name: Brandon Burt
#      Created at: Fri Apr 09 16:03:41 +0000 2021
# Tweets received: 63
#     Screen name: Peggy Stuart, Pragmatic Progressive
#      Created at: Fri Apr 09 16:03:42 +0000 2021
# Tweets received: 64
#     Screen name: Ros Johnson
#      Created at: Fri Apr 09 16:03:42 +0000 2021
# Tweets received: 65
#     Screen name: Maggie Stephens
#      Created at: Fri Apr 09 16:03:42 +0000 2021
# Tweets received: 66
#     Screen name: Maite
#      Created at: Fri Apr 09 16:03:42 +0000 2021
# Tweets received: 67
#     Screen name: Bryant
#      Created at: Fri Apr 09 16:03:42 +0000 2021
# Tweets received: 68
#     Screen name: Zane Schaefer
#      Created at: Fri Apr 09 16:03:43 +0000 2021
# Tweets received: 69
#     Screen name: High Skilled Immigration
#      Created at: Fri Apr 09 16:03:43 +0000 2021
# Tweets received: 70
#     Screen name: Laura rutmanis
#      Created at: Fri Apr 09 16:03:44 +0000 2021
# Tweets received: 71
#     Screen name: Yourvoicecounts
#      Created at: Fri Apr 09 16:03:44 +0000 2021
# Tweets received: 72
#     Screen name: Kayla
#      Created at: Fri Apr 09 16:03:44 +0000 2021
# Tweets received: 73
#     Screen name: Mulugeta Gebrekiros
#      Created at: Fri Apr 09 16:03:45 +0000 2021
# Tweets received: 74
#     Screen name: MS
#      Created at: Fri Apr 09 16:03:46 +0000 2021
# Tweets received: 75
#     Screen name: High Skilled Immigration
#      Created at: Fri Apr 09 16:03:46 +0000 2021
# Tweets received: 76
#     Screen name: Maite
#      Created at: Fri Apr 09 16:03:46 +0000 2021
# Tweets received: 77
#     Screen name: Kim
#      Created at: Fri Apr 09 16:03:46 +0000 2021
# Tweets received: 78
#     Screen name: Fed up in Illinois
#      Created at: Fri Apr 09 16:03:47 +0000 2021
# Tweets received: 79
#     Screen name: Firearms Lawyer
#      Created at: Fri Apr 09 16:03:47 +0000 2021
# Tweets received: 80
#     Screen name: Exposing The FBI Albuquerque
#      Created at: Fri Apr 09 16:03:47 +0000 2021
# Tweets received: 81
#     Screen name: semby24
#      Created at: Fri Apr 09 16:03:47 +0000 2021
# Tweets received: 82
#     Screen name: Peggy Stuart, Pragmatic Progressive
#      Created at: Fri Apr 09 16:03:48 +0000 2021
# Tweets received: 83
#     Screen name: Brenda
#      Created at: Fri Apr 09 16:03:48 +0000 2021
# Tweets received: 84
#     Screen name: Stephanie 😷
#      Created at: Fri Apr 09 16:03:48 +0000 2021
# Tweets received: 85
#     Screen name: Debbylu2u
#      Created at: Fri Apr 09 16:03:49 +0000 2021
# Tweets received: 86
#     Screen name: Maite
#      Created at: Fri Apr 09 16:03:50 +0000 2021
# Tweets received: 87
#     Screen name: archangel2
#      Created at: Fri Apr 09 16:03:50 +0000 2021
# Tweets received: 88
#     Screen name: Keith Martin
#      Created at: Fri Apr 09 16:03:50 +0000 2021
# Tweets received: 89
#     Screen name: Tallsquall #DemandBetterNews🌪
#      Created at: Fri Apr 09 16:03:50 +0000 2021
# Tweets received: 90
#     Screen name: lawrence delibro
#      Created at: Fri Apr 09 16:03:51 +0000 2021
# Tweets received: 91
#     Screen name: Edward Carl Lind lll
#      Created at: Fri Apr 09 16:03:51 +0000 2021
# Tweets received: 92
#     Screen name: Yaimara
#      Created at: Fri Apr 09 16:03:52 +0000 2021
# Tweets received: 93
#     Screen name: Don’tStandSoCloseToMe
#      Created at: Fri Apr 09 16:03:52 +0000 2021
# Tweets received: 94
#     Screen name: Jason Marquardt
#      Created at: Fri Apr 09 16:03:52 +0000 2021
# Tweets received: 95
#     Screen name: Mike Di Leonardo
#      Created at: Fri Apr 09 16:03:52 +0000 2021
# Tweets received: 96
#     Screen name: MadPat
#      Created at: Fri Apr 09 16:03:52 +0000 2021
# Tweets received: 97
#     Screen name: KitKatKitty
#      Created at: Fri Apr 09 16:03:53 +0000 2021
# Tweets received: 98
#     Screen name: Dissident Boomer Rube ∂(Megan)/∂(t)🇺🇸
#      Created at: Fri Apr 09 16:03:53 +0000 2021
# Tweets received: 99
#     Screen name: Maite
#      Created at: Fri Apr 09 16:03:53 +0000 2021
# Tweets received: 100
#     Screen name: Marianne Morris
#      Created at: Fri Apr 09 16:03:54 +0000 2021
# Tweets received: 101
#     Screen name: Sparkyman
#      Created at: Fri Apr 09 16:03:55 +0000 2021
# Tweets received: 102
#     Screen name: Pyramid45
#      Created at: Fri Apr 09 16:03:56 +0000 2021
# Tweets received: 103
#     Screen name: Gentleman Jim
#      Created at: Fri Apr 09 16:03:56 +0000 2021
# Tweets received: 104
#     Screen name: Dave Wood
#      Created at: Fri Apr 09 16:03:56 +0000 2021
# Tweets received: 105
#     Screen name: Ewindham3
#      Created at: Fri Apr 09 16:03:56 +0000 2021
# Tweets received: 106
#     Screen name: Senator Cortez Masto
#      Created at: Fri Apr 09 16:03:56 +0000 2021
# Tweets received: 107
#     Screen name: Seven Days In January
#      Created at: Fri Apr 09 16:03:56 +0000 2021
# Tweets received: 108
#     Screen name: Collision Imminent
#      Created at: Fri Apr 09 16:03:56 +0000 2021
# Tweets received: 109
#     Screen name: Laurel Krahn
#      Created at: Fri Apr 09 16:03:57 +0000 2021
# Tweets received: 110
#     Screen name: LaserHaas_eToys_legitimate_CEO
#      Created at: Fri Apr 09 16:03:58 +0000 2021
# Tweets received: 111
#     Screen name: R BatDavid
#      Created at: Fri Apr 09 16:03:58 +0000 2021
# Tweets received: 112
#     Screen name: Senzogaeri
#      Created at: Fri Apr 09 16:03:58 +0000 2021
# Tweets received: 113
#     Screen name: Kokob
#      Created at: Fri Apr 09 16:03:59 +0000 2021
# Tweets received: 114
#     Screen name: Tracy Scott
#      Created at: Fri Apr 09 16:04:00 +0000 2021
# Tweets received: 115
#     Screen name: Smilingsoozeq
#      Created at: Fri Apr 09 16:04:00 +0000 2021
# Tweets received: 116
#     Screen name: The Apostle Dave
#      Created at: Fri Apr 09 16:04:00 +0000 2021
# Tweets received: 117
#     Screen name: Laurel Pogue
#      Created at: Fri Apr 09 16:04:00 +0000 2021
# Tweets received: 118
#     Screen name: Zealot Als
#      Created at: Fri Apr 09 16:04:01 +0000 2021
# Tweets received: 119
#     Screen name: briscoeny
#      Created at: Fri Apr 09 16:04:02 +0000 2021
# Tweets received: 120
#     Screen name: WeNeedUnity
#      Created at: Fri Apr 09 16:04:02 +0000 2021
# Tweets received: 121
#     Screen name: What's Up Doc
#      Created at: Fri Apr 09 16:04:03 +0000 2021
# Tweets received: 122
#     Screen name: Derek Osgood
#      Created at: Fri Apr 09 16:04:03 +0000 2021
# Tweets received: 123
#     Screen name: Democrat for Decency 🇺🇸🇺🇸
#      Created at: Fri Apr 09 16:04:03 +0000 2021
# Tweets received: 124
#     Screen name: FLOrangeQueen
#      Created at: Fri Apr 09 16:04:04 +0000 2021
# Tweets received: 125
#     Screen name: John Rode
#      Created at: Fri Apr 09 16:04:05 +0000 2021
# Tweets received: 126
#     Screen name: Glenda Kay Campbell
#      Created at: Fri Apr 09 16:04:07 +0000 2021
# Tweets received: 127
#     Screen name: joey joe joe 🇺🇸
#      Created at: Fri Apr 09 16:04:07 +0000 2021
# Tweets received: 128
#     Screen name: TedCruzMustResign
#      Created at: Fri Apr 09 16:04:08 +0000 2021
# Tweets received: 129
#     Screen name: Keith Martin
#      Created at: Fri Apr 09 16:04:08 +0000 2021
# Tweets received: 130
#     Screen name: Two
#      Created at: Fri Apr 09 16:04:08 +0000 2021
# Tweets received: 131
#     Screen name: No-Corpoman
#      Created at: Fri Apr 09 16:04:08 +0000 2021
# Tweets received: 132
#     Screen name: ◻️ 阿努比比斯 Anubibis 🖐️😷☝️沉眠中
#      Created at: Fri Apr 09 16:04:08 +0000 2021
# Tweets received: 133
#     Screen name: CCL Triangle Chapter
#      Created at: Fri Apr 09 16:04:09 +0000 2021
# Tweets received: 134
#     Screen name: d kemp
#      Created at: Fri Apr 09 16:04:09 +0000 2021
# Tweets received: 135
#     Screen name: Benjamin Donkey
#      Created at: Fri Apr 09 16:04:10 +0000 2021
# Tweets received: 136
#     Screen name: TIMJPH
#      Created at: Fri Apr 09 16:04:11 +0000 2021
# Tweets received: 137
#     Screen name: USA Trump Man 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸
#      Created at: Fri Apr 09 16:04:11 +0000 2021
# Tweets received: 138
#     Screen name: Tampa News Force
#      Created at: Fri Apr 09 16:04:11 +0000 2021
# Tweets received: 139
#     Screen name: Ewindham3
#      Created at: Fri Apr 09 16:04:11 +0000 2021
# Tweets received: 140
#     Screen name: 📚451 😷👨🏻‍🚀🇺🇸🇨🇦
#      Created at: Fri Apr 09 16:04:11 +0000 2021
# Tweets received: 141
#     Screen name: Perseverance
#      Created at: Fri Apr 09 16:04:12 +0000 2021
# Tweets received: 142
#     Screen name: ❌Sharon Wood❌
#      Created at: Fri Apr 09 16:04:14 +0000 2021
# Tweets received: 143
#     Screen name: ThunderclapNewman
#      Created at: Fri Apr 09 16:04:14 +0000 2021
# Tweets received: 144
#     Screen name: Edward Carl Lind lll
#      Created at: Fri Apr 09 16:04:14 +0000 2021
# Tweets received: 145
#     Screen name: Ewindham3
#      Created at: Fri Apr 09 16:04:14 +0000 2021
# Tweets received: 146
#     Screen name: Arik Fetscher
#      Created at: Fri Apr 09 16:04:15 +0000 2021
# Tweets received: 147
#     Screen name: PKQ
#      Created at: Fri Apr 09 16:04:15 +0000 2021
# Tweets received: 148
#     Screen name: and so we crumble
#      Created at: Fri Apr 09 16:04:16 +0000 2021
# Tweets received: 149
#     Screen name: Klk
#      Created at: Fri Apr 09 16:04:16 +0000 2021
# Tweets received: 150
#     Screen name: Tiffany Davidson
#      Created at: Fri Apr 09 16:04:16 +0000 2021
# Tweets received: 151
#     Screen name: Blueberry Dawn: Karma, stomp the nitro, lets go!
#      Created at: Fri Apr 09 16:04:16 +0000 2021
# Tweets received: 152
#     Screen name: Nikkk
#      Created at: Fri Apr 09 16:04:16 +0000 2021
# Tweets received: 153
#     Screen name: Gilda I. Cartaya
#      Created at: Fri Apr 09 16:04:16 +0000 2021
# Tweets received: 154
#     Screen name: Adctxscott
#      Created at: Fri Apr 09 16:04:16 +0000 2021
# Tweets received: 155
#     Screen name: Robert Allen
#      Created at: Fri Apr 09 16:04:17 +0000 2021
# Tweets received: 156
#     Screen name: Jolvsdogs
#      Created at: Fri Apr 09 16:04:17 +0000 2021
# Tweets received: 157
#     Screen name: MKJ
#      Created at: Fri Apr 09 16:04:18 +0000 2021
# Tweets received: 158
#     Screen name: kingmandemo
#      Created at: Fri Apr 09 16:04:18 +0000 2021
# Tweets received: 159
#     Screen name: No-Corpoman
#      Created at: Fri Apr 09 16:04:18 +0000 2021
# Tweets received: 160
#     Screen name: Victor Olvera
#      Created at: Fri Apr 09 16:04:18 +0000 2021
# Tweets received: 161
#     Screen name: Fran Cast
#      Created at: Fri Apr 09 16:04:19 +0000 2021
# Tweets received: 162
#     Screen name: MKJ
#      Created at: Fri Apr 09 16:04:21 +0000 2021
# Tweets received: 163
#     Screen name: Mitch Smith
#      Created at: Fri Apr 09 16:04:22 +0000 2021
# Tweets received: 164
#     Screen name: Tracy Ladd
#      Created at: Fri Apr 09 16:04:21 +0000 2021
# Tweets received: 165
#     Screen name: Erica Phuckyah 🇨🇦💙🇺🇸
#      Created at: Fri Apr 09 16:04:22 +0000 2021
# Tweets received: 166
#     Screen name: Murph
#      Created at: Fri Apr 09 16:04:22 +0000 2021
# Tweets received: 167
#     Screen name: Sandra WilliamsLewis
#      Created at: Fri Apr 09 16:04:23 +0000 2021
# Tweets received: 168
#     Screen name: Renaissance Man - Not
#      Created at: Fri Apr 09 16:04:23 +0000 2021
# Tweets received: 169
#     Screen name: ❤💛💚Ephew Money💸🤑💹
#      Created at: Fri Apr 09 16:04:24 +0000 2021
# Tweets received: 170
#     Screen name: PayingAttentionAndConcerned
#      Created at: Fri Apr 09 16:04:24 +0000 2021
# Tweets received: 171
#     Screen name: Ebony Rose
#      Created at: Fri Apr 09 16:04:25 +0000 2021
# Tweets received: 172
#     Screen name: Debra Brady
#      Created at: Fri Apr 09 16:04:25 +0000 2021
# Tweets received: 173
#     Screen name: Gordon
#      Created at: Fri Apr 09 16:04:25 +0000 2021
# Tweets received: 174
#     Screen name: Annette N. Tchelka
#      Created at: Fri Apr 09 16:04:26 +0000 2021
# Tweets received: 175
#     Screen name: Americans 1st 🇺🇸♀️
#      Created at: Fri Apr 09 16:04:26 +0000 2021
# Tweets received: 176
#     Screen name: Chris M
#      Created at: Fri Apr 09 16:04:27 +0000 2021
# Tweets received: 177
#     Screen name: Yaimara
#      Created at: Fri Apr 09 16:04:27 +0000 2021
# Tweets received: 178
#     Screen name: Love America !
#      Created at: Fri Apr 09 16:04:27 +0000 2021
# Tweets received: 179
#     Screen name: Gabriel
#      Created at: Fri Apr 09 16:04:28 +0000 2021
# Tweets received: 180
#     Screen name: Tama McInness
#      Created at: Fri Apr 09 16:04:28 +0000 2021
# Tweets received: 181
#     Screen name: William Dean
#      Created at: Fri Apr 09 16:04:28 +0000 2021
# Tweets received: 182
#     Screen name: Hello My Name is: none of your business
#      Created at: Fri Apr 09 16:04:28 +0000 2021
# Tweets received: 183
#     Screen name: Rathekyn
#      Created at: Fri Apr 09 16:04:28 +0000 2021
# Tweets received: 184
#     Screen name: Karen Sadler
#      Created at: Fri Apr 09 16:04:30 +0000 2021
# Tweets received: 185
#     Screen name: Mar-a-lago Delenda Est!
#      Created at: Fri Apr 09 16:04:30 +0000 2021
# Tweets received: 186
#     Screen name: Keith McKinney
#      Created at: Fri Apr 09 16:04:31 +0000 2021
# Tweets received: 187
#     Screen name: Kitsune
#      Created at: Fri Apr 09 16:04:31 +0000 2021
# Tweets received: 188
#     Screen name: CV19HT🇺🇸
#      Created at: Fri Apr 09 16:04:32 +0000 2021
# Tweets received: 189
#     Screen name: Aneka Mayes
#      Created at: Fri Apr 09 16:04:33 +0000 2021
# Tweets received: 190
#     Screen name: StrangeMagic
#      Created at: Fri Apr 09 16:04:33 +0000 2021
# Tweets received: 191
#     Screen name: mary 🇮🇹
#      Created at: Fri Apr 09 16:04:33 +0000 2021
# Tweets received: 192
#     Screen name: Beijing Biden Election Infection 2020
#      Created at: Fri Apr 09 16:04:33 +0000 2021
# Tweets received: 193
#     Screen name: Shawn Morris
#      Created at: Fri Apr 09 16:04:34 +0000 2021
# Tweets received: 194
#     Screen name: zzelda01 Read my BIO
#      Created at: Fri Apr 09 16:04:34 +0000 2021
# Tweets received: 195
#     Screen name: Traci
#      Created at: Fri Apr 09 16:04:34 +0000 2021
# Tweets received: 196
#     Screen name: Anthony White
#      Created at: Fri Apr 09 16:04:35 +0000 2021
# Tweets received: 197
#     Screen name: Laurie Kleinbaum Fink, Ph.D.
#      Created at: Fri Apr 09 16:04:35 +0000 2021
# Tweets received: 198
#     Screen name: joanmemp2
#      Created at: Fri Apr 09 16:04:35 +0000 2021
# Tweets received: 199
#     Screen name: Wrong Way
#      Created at: Fri Apr 09 16:04:35 +0000 2021
# Tweets received: 200
#     Screen name: ÆMarling
#      Created at: Fri Apr 09 16:04:35 +0000 2021
# Tweets received: 201
#     Screen name: For Easton, Professor Farnsworth (Fren)
#      Created at: Fri Apr 09 16:04:36 +0000 2021
# Tweets received: 202
#     Screen name: Sawyer Brittain❤️(TextTrump 88022)
#      Created at: Fri Apr 09 16:04:36 +0000 2021
# Tweets received: 203
#     Screen name: Tammy Jackson
#      Created at: Fri Apr 09 16:04:36 +0000 2021
# Tweets received: 204
#     Screen name: Perry Lambert
#      Created at: Fri Apr 09 16:04:37 +0000 2021
# Tweets received: 205
#     Screen name: † Crusader
#      Created at: Fri Apr 09 16:04:37 +0000 2021
# Tweets received: 206
#     Screen name: Maziyar Farhoud👑
#      Created at: Fri Apr 09 16:04:37 +0000 2021
# Tweets received: 207
#     Screen name: Mad White Guy🙃🥴🇺🇲🏴󠁧󠁢󠁷󠁬󠁳󠁿🌊
#      Created at: Fri Apr 09 16:04:37 +0000 2021
# Tweets received: 208
#     Screen name: Chris M
#      Created at: Fri Apr 09 16:04:38 +0000 2021
# Tweets received: 209
#     Screen name: Pamela K. Palmer, J.D.
#      Created at: Fri Apr 09 16:04:38 +0000 2021
# Tweets received: 210
#     Screen name: Harry Mack II
#      Created at: Fri Apr 09 16:04:39 +0000 2021
# Tweets received: 211
#     Screen name: Saxon Walker - New & Improved
#      Created at: Fri Apr 09 16:04:40 +0000 2021
# Tweets received: 212
#     Screen name: Tama McInness
#      Created at: Fri Apr 09 16:04:40 +0000 2021
# Tweets received: 213
#     Screen name: ian2
#      Created at: Fri Apr 09 16:04:40 +0000 2021
# Tweets received: 214
#     Screen name: isabella
#      Created at: Fri Apr 09 16:04:41 +0000 2021
# Tweets received: 215
#     Screen name: Electoral College Dropout
#      Created at: Fri Apr 09 16:04:41 +0000 2021
# Tweets received: 216
#     Screen name: J
#      Created at: Fri Apr 09 16:04:41 +0000 2021
# Tweets received: 217
#     Screen name: Lucas Schulz
#      Created at: Fri Apr 09 16:04:42 +0000 2021
# Tweets received: 218
#     Screen name: Chris M
#      Created at: Fri Apr 09 16:04:43 +0000 2021
# Tweets received: 219
#     Screen name: Remington
#      Created at: Fri Apr 09 16:04:43 +0000 2021
# Tweets received: 220
#     Screen name: DanaNcolorado
#      Created at: Fri Apr 09 16:04:43 +0000 2021
# Tweets received: 221
#     Screen name: Cindy
#      Created at: Fri Apr 09 16:04:43 +0000 2021
# Tweets received: 222
#     Screen name: D Elvin klemme
#      Created at: Fri Apr 09 16:04:45 +0000 2021
# Tweets received: 223
#     Screen name: Bruce
#      Created at: Fri Apr 09 16:04:45 +0000 2021
# Tweets received: 224
#     Screen name: Susie Gurwitz
#      Created at: Fri Apr 09 16:04:45 +0000 2021
# Tweets received: 225
#     Screen name: Julia La Riva
#      Created at: Fri Apr 09 16:04:45 +0000 2021
# Tweets received: 226
#     Screen name: Richa
#      Created at: Fri Apr 09 16:04:46 +0000 2021
# Tweets received: 227
#     Screen name: Grift Eschewer
#      Created at: Fri Apr 09 16:04:47 +0000 2021
# Tweets received: 228
#     Screen name: IrishRick
#      Created at: Fri Apr 09 16:04:47 +0000 2021
# Tweets received: 229
#     Screen name: Edward Carl Lind lll
#      Created at: Fri Apr 09 16:04:48 +0000 2021
# Tweets received: 230
#     Screen name: Amy W
#      Created at: Fri Apr 09 16:04:48 +0000 2021
# Tweets received: 231
#     Screen name: We’re A Third World Country Wearing A Gucci Belt
#      Created at: Fri Apr 09 16:04:49 +0000 2021
# Tweets received: 232
#     Screen name: 屎鳩胸奴人@tt
#      Created at: Fri Apr 09 16:04:49 +0000 2021
# Tweets received: 233
#     Screen name: Cindy
#      Created at: Fri Apr 09 16:04:50 +0000 2021
# Tweets received: 234
#     Screen name: Kathleen Concannon
#      Created at: Fri Apr 09 16:04:50 +0000 2021
# Tweets received: 235
#     Screen name: Battleriverbabe
#      Created at: Fri Apr 09 16:04:50 +0000 2021
# Tweets received: 236
#     Screen name: Alan M Reck
#      Created at: Fri Apr 09 16:04:51 +0000 2021
# Tweets received: 237
#     Screen name: Stay. Home. or wear a mask
#      Created at: Fri Apr 09 16:04:51 +0000 2021
# Tweets received: 238
#     Screen name: d kemp
#      Created at: Fri Apr 09 16:04:52 +0000 2021
# Tweets received: 239
#     Screen name: yordii
#      Created at: Fri Apr 09 16:04:52 +0000 2021
# Tweets received: 240
#     Screen name: Cans
#      Created at: Fri Apr 09 16:04:53 +0000 2021
# Tweets received: 241
#     Screen name: briscoeny
#      Created at: Fri Apr 09 16:04:53 +0000 2021
# Tweets received: 242
#     Screen name: WordsMatter (Stayin'🏠)
#      Created at: Fri Apr 09 16:04:53 +0000 2021
# Tweets received: 243
#     Screen name: Beam Me Up Scotty
#      Created at: Fri Apr 09 16:04:54 +0000 2021
# Tweets received: 244
#     Screen name: One Nasty Woman
#      Created at: Fri Apr 09 16:04:54 +0000 2021
# Tweets received: 245
#     Screen name: ACAB - BLM!
#      Created at: Fri Apr 09 16:04:54 +0000 2021
# Tweets received: 246
#     Screen name: 💙🌊🌊🌊Joshua Linus💙Blue2022
#      Created at: Fri Apr 09 16:04:55 +0000 2021
# Tweets received: 247
#     Screen name: Yaimara
#      Created at: Fri Apr 09 16:04:55 +0000 2021
# Tweets received: 248
#     Screen name: TruthIsTruth
#      Created at: Fri Apr 09 16:04:55 +0000 2021
# Tweets received: 249
#     Screen name: HagereyKibretey
#      Created at: Fri Apr 09 16:04:56 +0000 2021
# Tweets received: 250
#     Screen name: Elsie
#      Created at: Fri Apr 09 16:04:58 +0000 2021
# Tweets received: 251
#     Screen name: KeptByGod
#      Created at: Fri Apr 09 16:04:58 +0000 2021
# Tweets received: 252
#     Screen name: Hannah Delahanty
#      Created at: Fri Apr 09 16:04:59 +0000 2021
# Tweets received: 253
#     Screen name: Cozy16
#      Created at: Fri Apr 09 16:05:00 +0000 2021
# Tweets received: 254
#     Screen name: Chris M
#      Created at: Fri Apr 09 16:05:00 +0000 2021
# Tweets received: 255
#     Screen name: FP Smith
#      Created at: Fri Apr 09 16:05:01 +0000 2021
# Tweets received: 256
#     Screen name: Rickster Rickster
#      Created at: Fri Apr 09 16:05:01 +0000 2021
# Tweets received: 257
#     Screen name: LindaLou143
#      Created at: Fri Apr 09 16:05:01 +0000 2021
# Tweets received: 258
#     Screen name: Sophia - Mask pls! #StandWithFarmers#NoVotetoBJP
#      Created at: Fri Apr 09 16:05:01 +0000 2021
# Tweets received: 259
#     Screen name: do minh thanh
#      Created at: Fri Apr 09 16:05:01 +0000 2021
# Tweets received: 260
#     Screen name: WHO~ 😷👍🇺🇸
#      Created at: Fri Apr 09 16:05:03 +0000 2021
# Tweets received: 261
#     Screen name: Peter Andreyev
#      Created at: Fri Apr 09 16:05:04 +0000 2021
# Tweets received: 262
#     Screen name: 🌊KaReN 🌊McCoNnElL🌊
#      Created at: Fri Apr 09 16:05:04 +0000 2021
# Tweets received: 263
#     Screen name: David Klock
#      Created at: Fri Apr 09 16:05:05 +0000 2021
# Tweets received: 264
#     Screen name: American Patriot TGM
#      Created at: Fri Apr 09 16:05:05 +0000 2021
# Tweets received: 265
#     Screen name: TIMJPH
#      Created at: Fri Apr 09 16:05:05 +0000 2021
# Tweets received: 266
#     Screen name: Codeweiller 🌊
#      Created at: Fri Apr 09 16:05:05 +0000 2021
# Tweets received: 267
#     Screen name: Naraj Lloyd
#      Created at: Fri Apr 09 16:05:06 +0000 2021
# Tweets received: 268
#     Screen name: ᗩᖇYᗩ ᔕTᗩᖇK ❄
#      Created at: Fri Apr 09 16:05:06 +0000 2021
# Tweets received: 269
#     Screen name: Travis County GOP
#      Created at: Fri Apr 09 16:05:06 +0000 2021
# Tweets received: 270
#     Screen name: Luka
#      Created at: Fri Apr 09 16:05:06 +0000 2021
# Tweets received: 271
#     Screen name: Icarus Gabor
#      Created at: Fri Apr 09 16:05:07 +0000 2021
# Tweets received: 272
#     Screen name: briscoeny
#      Created at: Fri Apr 09 16:05:08 +0000 2021
# Tweets received: 273
#     Screen name: Emma
#      Created at: Fri Apr 09 16:05:08 +0000 2021
# Tweets received: 274
#     Screen name: nathan r jessup
#      Created at: Fri Apr 09 16:05:09 +0000 2021
# Tweets received: 275
#     Screen name: BC
#      Created at: Fri Apr 09 16:05:09 +0000 2021
# Tweets received: 276
#     Screen name: Tedros Atakilti 11
#      Created at: Fri Apr 09 16:05:09 +0000 2021
# Tweets received: 277
#     Screen name: Bre * Bring On Justice #TrumpWon
#      Created at: Fri Apr 09 16:05:09 +0000 2021
# Tweets received: 278
#     Screen name: Rob
#      Created at: Fri Apr 09 16:05:09 +0000 2021
# Tweets received: 279
#     Screen name: Amy W
#      Created at: Fri Apr 09 16:05:09 +0000 2021
# Tweets received: 280
#     Screen name: LuffagusOfficial
#      Created at: Fri Apr 09 16:05:10 +0000 2021
# Tweets received: 281
#     Screen name: Michael Holliday
#      Created at: Fri Apr 09 16:05:10 +0000 2021
# Tweets received: 282
#     Screen name: Gramnagorb
#      Created at: Fri Apr 09 16:05:10 +0000 2021
# Tweets received: 283
#     Screen name: MYO
#      Created at: Fri Apr 09 16:05:11 +0000 2021
# Tweets received: 284
#     Screen name: Rivendell Rock Jewel
#      Created at: Fri Apr 09 16:05:11 +0000 2021
# Tweets received: 285
#     Screen name: Magic
#      Created at: Fri Apr 09 16:05:12 +0000 2021
# Tweets received: 286
#     Screen name: Cynthia Petek
#      Created at: Fri Apr 09 16:05:12 +0000 2021
# Tweets received: 287
#     Screen name: Capemarine
#      Created at: Fri Apr 09 16:05:13 +0000 2021
# Tweets received: 288
#     Screen name: BC
#      Created at: Fri Apr 09 16:05:14 +0000 2021
# Tweets received: 289
#     Screen name: Freyja White
#      Created at: Fri Apr 09 16:05:14 +0000 2021
# Tweets received: 290
#     Screen name: JoeZee A/C Suspended - Starting over.
#      Created at: Fri Apr 09 16:05:14 +0000 2021
# Tweets received: 291
#     Screen name: Irene
#      Created at: Fri Apr 09 16:05:14 +0000 2021
# Tweets received: 292
#     Screen name: Deidra
#      Created at: Fri Apr 09 16:05:14 +0000 2021
# Tweets received: 293
#     Screen name: Donette Moore
#      Created at: Fri Apr 09 16:05:14 +0000 2021
# Tweets received: 294
#     Screen name: Silas Hunter 🙂
#      Created at: Fri Apr 09 16:05:16 +0000 2021
# Tweets received: 295
#     Screen name: ivis
#      Created at: Fri Apr 09 16:05:16 +0000 2021
# Tweets received: 296
#     Screen name: Kassahun ካሳሁን
#      Created at: Fri Apr 09 16:05:16 +0000 2021
# Tweets received: 297
#     Screen name: d kemp
#      Created at: Fri Apr 09 16:05:16 +0000 2021
# Tweets received: 298
#     Screen name: REFORMTHEFILIBUSTER 🇺🇸
#      Created at: Fri Apr 09 16:05:17 +0000 2021
# Tweets received: 299
#     Screen name: Brandon Houser
#      Created at: Fri Apr 09 16:05:17 +0000 2021
# Tweets received: 300
#     Screen name: PatrickAtwood
#      Created at: Fri Apr 09 16:05:17 +0000 2021
# Tweets received: 301
#     Screen name: Jen #GoodTrouble
#      Created at: Fri Apr 09 16:05:17 +0000 2021
# Tweets received: 302
#     Screen name: No PlanetB B
#      Created at: Fri Apr 09 16:05:18 +0000 2021
# Tweets received: 303
#     Screen name: Neanderthal Pony Soldier
#      Created at: Fri Apr 09 16:05:18 +0000 2021
# Tweets received: 304
#     Screen name: Freedom
#      Created at: Fri Apr 09 16:05:19 +0000 2021
# Tweets received: 305
#     Screen name: QinxiaoMin
#      Created at: Fri Apr 09 16:05:20 +0000 2021
# Tweets received: 306
#     Screen name: Michael Buchanan
#      Created at: Fri Apr 09 16:05:20 +0000 2021
# Tweets received: 307
#     Screen name: Cathy DeRose
#      Created at: Fri Apr 09 16:05:21 +0000 2021
# Tweets received: 308
#     Screen name: Martin Smith
#      Created at: Fri Apr 09 16:05:22 +0000 2021
# Tweets received: 309
#     Screen name: John
#      Created at: Fri Apr 09 16:05:24 +0000 2021
# Tweets received: 310
#     Screen name: Wayne Winski
#      Created at: Fri Apr 09 16:05:24 +0000 2021
# Tweets received: 311
#     Screen name: Maureen Copatch
#      Created at: Fri Apr 09 16:05:25 +0000 2021
# Tweets received: 312
#     Screen name: FutureTimes15
#      Created at: Fri Apr 09 16:05:25 +0000 2021
# Tweets received: 313
#     Screen name: Marisela Lopez
#      Created at: Fri Apr 09 16:05:25 +0000 2021
# Tweets received: 314
#     Screen name: PresleyTiger
#      Created at: Fri Apr 09 16:05:25 +0000 2021
# Tweets received: 315
#     Screen name: Tummler (means... Connector & Troublemaker)
#      Created at: Fri Apr 09 16:05:25 +0000 2021
# Tweets received: 316
#     Screen name: MelindaWS
#      Created at: Fri Apr 09 16:05:25 +0000 2021
# Tweets received: 317
#     Screen name: Fiacresgirl, live from 🤡🌎
#      Created at: Fri Apr 09 16:05:27 +0000 2021
# Tweets received: 318
#     Screen name: Derek Osgood
#      Created at: Fri Apr 09 16:05:28 +0000 2021
# Tweets received: 319
#     Screen name: Truth
#      Created at: Fri Apr 09 16:05:29 +0000 2021
# Tweets received: 320
#     Screen name: Usedtobe_JohnRJohnson
#      Created at: Fri Apr 09 16:05:29 +0000 2021
# Tweets received: 321
#     Screen name: American Resurrection
#      Created at: Fri Apr 09 16:05:29 +0000 2021
# Tweets received: 322
#     Screen name: Thomas
#      Created at: Fri Apr 09 16:05:29 +0000 2021
# Tweets received: 323
#     Screen name: Doug Basham
#      Created at: Fri Apr 09 16:05:29 +0000 2021
# Tweets received: 324
#     Screen name: J
#      Created at: Fri Apr 09 16:05:31 +0000 2021
# Tweets received: 325
#     Screen name: We did it! We did it Joe!
#      Created at: Fri Apr 09 16:05:32 +0000 2021
# Tweets received: 326
#     Screen name: TheEternalAbyss
#      Created at: Fri Apr 09 16:05:32 +0000 2021
# Tweets received: 327
#     Screen name: CV19HT🇺🇸
#      Created at: Fri Apr 09 16:05:33 +0000 2021
# Tweets received: 328
#     Screen name: Tummler (means... Connector & Troublemaker)
#      Created at: Fri Apr 09 16:05:33 +0000 2021
# Tweets received: 329
#     Screen name: Realbookmaker2
#      Created at: Fri Apr 09 16:05:35 +0000 2021
# Tweets received: 330
#     Screen name: Shelley
#      Created at: Fri Apr 09 16:05:35 +0000 2021
# Tweets received: 331
#     Screen name: Deborah Goldsmith
#      Created at: Fri Apr 09 16:05:35 +0000 2021
# Tweets received: 332
#     Screen name: nihal
#      Created at: Fri Apr 09 16:05:37 +0000 2021
# Tweets received: 333
#     Screen name: menswaxingstore
#      Created at: Fri Apr 09 16:05:37 +0000 2021
# Tweets received: 334
#     Screen name: Uncle Giggles
#      Created at: Fri Apr 09 16:05:38 +0000 2021
# Tweets received: 335
#     Screen name: Tiffany Davidson
#      Created at: Fri Apr 09 16:05:38 +0000 2021
# Tweets received: 336
#     Screen name: Mike Ryan
#      Created at: Fri Apr 09 16:05:39 +0000 2021
# Tweets received: 337
#     Screen name: Sommerset1616
#      Created at: Fri Apr 09 16:05:39 +0000 2021
# Tweets received: 338
#     Screen name: dbarabin
#      Created at: Fri Apr 09 16:05:41 +0000 2021
# Tweets received: 339
#     Screen name: Fred F. Tondalo Jr.
#      Created at: Fri Apr 09 16:05:41 +0000 2021
# Tweets received: 340
#     Screen name: David Yelton
#      Created at: Fri Apr 09 16:05:41 +0000 2021
# Tweets received: 341
#     Screen name: Martin Smith
#      Created at: Fri Apr 09 16:05:41 +0000 2021
# Tweets received: 342
#     Screen name: Sellen
#      Created at: Fri Apr 09 16:05:42 +0000 2021
# Tweets received: 343
#     Screen name: Titanium Koala
#      Created at: Fri Apr 09 16:05:42 +0000 2021
# Tweets received: 344
#     Screen name: ivis
#      Created at: Fri Apr 09 16:05:42 +0000 2021
# Tweets received: 345
#     Screen name: chumpfortrump
#      Created at: Fri Apr 09 16:05:42 +0000 2021
# Tweets received: 346
#     Screen name: archangel2
#      Created at: Fri Apr 09 16:05:42 +0000 2021
# Tweets received: 347
#     Screen name: Sarah Zhou
#      Created at: Fri Apr 09 16:05:43 +0000 2021
# Tweets received: 348
#     Screen name: Michael MoneyMike James-Valderas
#      Created at: Fri Apr 09 16:05:43 +0000 2021
# Tweets received: 349
#     Screen name: patb
#      Created at: Fri Apr 09 16:05:44 +0000 2021
# Tweets received: 350
#     Screen name: Anthony White
#      Created at: Fri Apr 09 16:05:44 +0000 2021
# Tweets received: 351
#     Screen name: wit_t
#      Created at: Fri Apr 09 16:05:44 +0000 2021
# Tweets received: 352
#     Screen name: Phoenix Rising- Firey Mythological Neanderthal
#      Created at: Fri Apr 09 16:05:45 +0000 2021
# Tweets received: 353
#     Screen name: d kemp
#      Created at: Fri Apr 09 16:05:46 +0000 2021
# Tweets received: 354
#     Screen name: EHW
#      Created at: Fri Apr 09 16:05:46 +0000 2021
# Tweets received: 355
#     Screen name: Franksandbeans48
#      Created at: Fri Apr 09 16:05:47 +0000 2021
# Tweets received: 356
#     Screen name: Protect Our Care
#      Created at: Fri Apr 09 16:05:47 +0000 2021
# Tweets received: 357
#     Screen name: NOW IS THE TIME
#      Created at: Fri Apr 09 16:05:47 +0000 2021
# Tweets received: 358
#     Screen name: Derek Asbury
#      Created at: Fri Apr 09 16:05:47 +0000 2021
# Tweets received: 359
#     Screen name: ☂️🌊☠Moral Highground Atop Mass Graves☠🌊☂️
#      Created at: Fri Apr 09 16:05:48 +0000 2021
# Tweets received: 360
#     Screen name: Edward Carl Lind lll
#      Created at: Fri Apr 09 16:05:49 +0000 2021
# Tweets received: 361
#     Screen name: Seven Days In January
#      Created at: Fri Apr 09 16:05:49 +0000 2021
# Tweets received: 362
#     Screen name: @TrophyHusband
#      Created at: Fri Apr 09 16:05:50 +0000 2021
# Tweets received: 363
#     Screen name: AmericanRasta
#      Created at: Fri Apr 09 16:05:50 +0000 2021
# Tweets received: 364
#     Screen name: Axe
#      Created at: Fri Apr 09 16:05:50 +0000 2021
# Tweets received: 365
#     Screen name: Senior Chief
#      Created at: Fri Apr 09 16:05:50 +0000 2021
# Tweets received: 366
#     Screen name: Colleen aka Craftykid 🇺🇸
#      Created at: Fri Apr 09 16:05:51 +0000 2021
# Tweets received: 367
#     Screen name: Blinktip
#      Created at: Fri Apr 09 16:05:52 +0000 2021
# Tweets received: 368
#     Screen name: Senator Ron Johnson
#      Created at: Fri Apr 09 16:05:52 +0000 2021
# Tweets received: 369
#     Screen name: We Dumped Trump!!!
#      Created at: Fri Apr 09 16:05:52 +0000 2021
# Tweets received: 370
#     Screen name: Donna G No More
#      Created at: Fri Apr 09 16:05:52 +0000 2021
# Tweets received: 371
#     Screen name: Bagator #RESIST🏡
#      Created at: Fri Apr 09 16:05:53 +0000 2021
# Tweets received: 372
#     Screen name: all100Senators
#      Created at: Fri Apr 09 16:05:53 +0000 2021
# Tweets received: 373
#     Screen name: Vicki D. 🇺🇸
#      Created at: Fri Apr 09 16:05:53 +0000 2021
# Tweets received: 374
#     Screen name: Pete Wyckoff
#      Created at: Fri Apr 09 16:05:53 +0000 2021
# Tweets received: 375
#     Screen name: Penelope
#      Created at: Fri Apr 09 16:05:53 +0000 2021
# Tweets received: 376
#     Screen name: Don
#      Created at: Fri Apr 09 16:05:54 +0000 2021
# Tweets received: 377
#     Screen name: R BatDavid
#      Created at: Fri Apr 09 16:05:55 +0000 2021
# Tweets received: 378
#     Screen name: Danielle
#      Created at: Fri Apr 09 16:05:55 +0000 2021
# Tweets received: 379
#     Screen name: NOW IS THE TIME
#      Created at: Fri Apr 09 16:05:55 +0000 2021
# Tweets received: 380
#     Screen name: J
#      Created at: Fri Apr 09 16:05:55 +0000 2021
# Tweets received: 381
#     Screen name: Colleen Maher
#      Created at: Fri Apr 09 16:05:56 +0000 2021
# Tweets received: 382
#     Screen name: Rick Scott
#      Created at: Fri Apr 09 16:05:56 +0000 2021
# Tweets received: 383
#     Screen name: Beam Me Up Scotty
#      Created at: Fri Apr 09 16:05:56 +0000 2021
# Tweets received: 384
#     Screen name: Neamin Zeleke
#      Created at: Fri Apr 09 16:05:56 +0000 2021
# Tweets received: 385
#     Screen name: Rick Scott
#      Created at: Fri Apr 09 16:05:56 +0000 2021
# Tweets received: 386
#     Screen name: BB
#      Created at: Fri Apr 09 16:05:57 +0000 2021
# Tweets received: 387
#     Screen name: Aberhet
#      Created at: Fri Apr 09 16:05:57 +0000 2021
# Tweets received: 388
#     Screen name: WELCOME TO THE NEW WORLD ORDER
#      Created at: Fri Apr 09 16:05:57 +0000 2021
# Tweets received: 389
#     Screen name: Bgdeuce13🇺🇸🏓📹📸🏖️
#      Created at: Fri Apr 09 16:05:57 +0000 2021
# Tweets received: 390
#     Screen name: richo💛❤ #IstandwithTigray
#      Created at: Fri Apr 09 16:05:58 +0000 2021
# Tweets received: 391
#     Screen name: 🌊 GoHilary 🌊
#      Created at: Fri Apr 09 16:05:58 +0000 2021
# Tweets received: 392
#     Screen name: Debbie Nunn
#      Created at: Fri Apr 09 16:06:00 +0000 2021
# Tweets received: 393
#     Screen name: Douglas Brown
#      Created at: Fri Apr 09 16:06:00 +0000 2021
# Tweets received: 394
#     Screen name: all100Senators
#      Created at: Fri Apr 09 16:06:01 +0000 2021
# Tweets received: 395
#     Screen name: all100Senators
#      Created at: Fri Apr 09 16:06:01 +0000 2021
# Tweets received: 396
#     Screen name: REFORMTHEFILIBUSTER 🇺🇸
#      Created at: Fri Apr 09 16:06:01 +0000 2021
# Tweets received: 397
#     Screen name: Marilyn Muller
#      Created at: Fri Apr 09 16:06:01 +0000 2021
# Tweets received: 398
#     Screen name: BB
#      Created at: Fri Apr 09 16:06:02 +0000 2021
# Tweets received: 399
#     Screen name: Missy
#      Created at: Fri Apr 09 16:06:02 +0000 2021
# Tweets received: 400
#     Screen name: Ricky Shanks
#      Created at: Fri Apr 09 16:06:03 +0000 2021
# Tweets received: 401
#     Screen name: P. A. Nichols
#      Created at: Fri Apr 09 16:06:03 +0000 2021
# Tweets received: 402
#     Screen name: Reuy_Solomon(ርኡይ)💛❤️✊🏾
#      Created at: Fri Apr 09 16:06:03 +0000 2021
# Tweets received: 403
#     Screen name: SnowInJuly
#      Created at: Fri Apr 09 16:06:03 +0000 2021
# Tweets received: 404
#     Screen name: April Adamson
#      Created at: Fri Apr 09 16:06:03 +0000 2021
# Tweets received: 405
#     Screen name: One Nasty Woman
#      Created at: Fri Apr 09 16:06:04 +0000 2021
# Tweets received: 406
#     Screen name: Sharon
#      Created at: Fri Apr 09 16:06:04 +0000 2021
# Tweets received: 407
#     Screen name: @edenzberhe
#      Created at: Fri Apr 09 16:06:05 +0000 2021
# Tweets received: 408
#     Screen name: Kevin Baker
#      Created at: Fri Apr 09 16:06:06 +0000 2021
# Tweets received: 409
#     Screen name: Ilene
#      Created at: Fri Apr 09 16:06:07 +0000 2021
# Tweets received: 410
#     Screen name: Rolled Up Sleeves
#      Created at: Fri Apr 09 16:06:07 +0000 2021
# Tweets received: 411
#     Screen name: Silas Hunter 🙂
#      Created at: Fri Apr 09 16:06:07 +0000 2021
# Tweets received: 412
#     Screen name: Toonces The Driving Cat
#      Created at: Fri Apr 09 16:06:08 +0000 2021
# Tweets received: 413
#     Screen name: GovTrack.🇺🇸
#      Created at: Fri Apr 09 16:06:08 +0000 2021
# Tweets received: 414
#     Screen name: TIMJPH
#      Created at: Fri Apr 09 16:06:08 +0000 2021
# Tweets received: 415
#     Screen name: COOL VFX
#      Created at: Fri Apr 09 16:06:08 +0000 2021
# Tweets received: 416
#     Screen name: freedomforever
#      Created at: Fri Apr 09 16:06:09 +0000 2021
# Tweets received: 417
#     Screen name: Rowan Wolfe🏳️‍🌈USAF
#      Created at: Fri Apr 09 16:06:09 +0000 2021
# Tweets received: 418
#     Screen name: Never Forget Jan. 6th, 2021
#      Created at: Fri Apr 09 16:06:09 +0000 2021
# Tweets received: 419
#     Screen name: Sho'Nuff Skywalker
#      Created at: Fri Apr 09 16:06:10 +0000 2021
# Tweets received: 420
#     Screen name: Cookie
#      Created at: Fri Apr 09 16:06:12 +0000 2021
# Tweets received: 421
#     Screen name: Meth Gator Trainer
#      Created at: Fri Apr 09 16:06:12 +0000 2021
# Tweets received: 422
#     Screen name: სასკოლო კვლევები
#      Created at: Fri Apr 09 16:06:12 +0000 2021
# Tweets received: 423
#     Screen name: DEFEAT THE LIES- VOTE BLUE 2022
#      Created at: Fri Apr 09 16:06:13 +0000 2021
# Tweets received: 424
#     Screen name: Maureen Pride
#      Created at: Fri Apr 09 16:06:13 +0000 2021
# Tweets received: 425
#     Screen name: Hold them accountable 🇨🇦🇺🇸
#      Created at: Fri Apr 09 16:06:14 +0000 2021
# Tweets received: 426
#     Screen name: Dem Pride
#      Created at: Fri Apr 09 16:06:14 +0000 2021
# Tweets received: 427
#     Screen name: Seven Days In January
#      Created at: Fri Apr 09 16:06:15 +0000 2021
# Tweets received: 428
#     Screen name: MrsDubya 😷
#      Created at: Fri Apr 09 16:06:15 +0000 2021
# Tweets received: 429
#     Screen name: Kimberly  (Kimbob)
#      Created at: Fri Apr 09 16:06:16 +0000 2021
# Tweets received: 430
#     Screen name: slick
#      Created at: Fri Apr 09 16:06:16 +0000 2021
# Tweets received: 431
#     Screen name: Realbookmaker2
#      Created at: Fri Apr 09 16:06:16 +0000 2021
# Tweets received: 432
#     Screen name: J. Domino Frost
#      Created at: Fri Apr 09 16:06:16 +0000 2021
# Tweets received: 433
#     Screen name: King
#      Created at: Fri Apr 09 16:06:17 +0000 2021
# Tweets received: 434
#     Screen name: scubaemt
#      Created at: Fri Apr 09 16:06:17 +0000 2021
# Tweets received: 435
#     Screen name: TIMJPH
#      Created at: Fri Apr 09 16:06:17 +0000 2021
# Tweets received: 436
#     Screen name: Bob Catinazzo
#      Created at: Fri Apr 09 16:06:17 +0000 2021
# Tweets received: 437
#     Screen name: Denise Holland
#      Created at: Fri Apr 09 16:06:17 +0000 2021
# Tweets received: 438
#     Screen name: Rosemarie Johnson
#      Created at: Fri Apr 09 16:06:17 +0000 2021
# Tweets received: 439
#     Screen name: Patriota Penquista*🇨🇱
#      Created at: Fri Apr 09 16:06:18 +0000 2021
# Tweets received: 440
#     Screen name: SuperSerial
#      Created at: Fri Apr 09 16:06:19 +0000 2021
# Tweets received: 441
#     Screen name: Jesse Pierce 🚲
#      Created at: Fri Apr 09 16:06:19 +0000 2021
# Tweets received: 442
#     Screen name: phoenix2life
#      Created at: Fri Apr 09 16:06:19 +0000 2021
# Tweets received: 443
#     Screen name: CAROLYN FITZGERALD
#      Created at: Fri Apr 09 16:06:19 +0000 2021
# Tweets received: 444
#     Screen name: Murray Ranson
#      Created at: Fri Apr 09 16:06:20 +0000 2021
# Tweets received: 445
#     Screen name: Anybuddy
#      Created at: Fri Apr 09 16:06:19 +0000 2021
# Tweets received: 446
#     Screen name: Dan Costigan
#      Created at: Fri Apr 09 16:06:21 +0000 2021
# Tweets received: 447
#     Screen name: Ernest Hua
#      Created at: Fri Apr 09 16:06:22 +0000 2021
# Tweets received: 448
#     Screen name: Maxim Guerin
#      Created at: Fri Apr 09 16:06:23 +0000 2021
# Tweets received: 449
#     Screen name: Magic City Madman
#      Created at: Fri Apr 09 16:06:23 +0000 2021
# Tweets received: 450
#     Screen name: HowsThatNow
#      Created at: Fri Apr 09 16:06:24 +0000 2021
# Tweets received: 451
#     Screen name: SunjayJK✾DIVERSITY
#      Created at: Fri Apr 09 16:06:25 +0000 2021
# Tweets received: 452
#     Screen name: Eileen Sullivan
#      Created at: Fri Apr 09 16:06:26 +0000 2021
# Tweets received: 453
#     Screen name: Happiness is Here Again 🌊🌊🌊
#      Created at: Fri Apr 09 16:06:27 +0000 2021
# Tweets received: 454
#     Screen name: Electoral College Dropout
#      Created at: Fri Apr 09 16:06:28 +0000 2021
# Tweets received: 455
#     Screen name: Christina ❤🤍💙
#      Created at: Fri Apr 09 16:06:28 +0000 2021
# Tweets received: 456
#     Screen name: Edith Miller
#      Created at: Fri Apr 09 16:06:29 +0000 2021
# Tweets received: 457
#     Screen name: Charles Kelly
#      Created at: Fri Apr 09 16:06:29 +0000 2021
# Tweets received: 458
#     Screen name: Harvey G. Cohen
#      Created at: Fri Apr 09 16:06:30 +0000 2021
# Tweets received: 459
#     Screen name: gorilla biscuits
#      Created at: Fri Apr 09 16:06:31 +0000 2021
# Tweets received: 460
#     Screen name: High Skilled Immigration
#      Created at: Fri Apr 09 16:06:31 +0000 2021
# Tweets received: 461
#     Screen name: AmericanRasta
#      Created at: Fri Apr 09 16:06:32 +0000 2021
# Tweets received: 462
#     Screen name: TK One
#      Created at: Fri Apr 09 16:06:32 +0000 2021
# Tweets received: 463
#     Screen name: ronnie
#      Created at: Fri Apr 09 16:06:33 +0000 2021
# Tweets received: 464
#     Screen name: Lynn Walton
#      Created at: Fri Apr 09 16:06:33 +0000 2021
# Tweets received: 465
#     Screen name: Robert McMillan
#      Created at: Fri Apr 09 16:06:34 +0000 2021
# Tweets received: 466
#     Screen name: Badger3k
#      Created at: Fri Apr 09 16:06:34 +0000 2021
# Tweets received: 467
#     Screen name: Fred F. Tondalo Jr.
#      Created at: Fri Apr 09 16:06:34 +0000 2021
# Tweets received: 468
#     Screen name: Maite
#      Created at: Fri Apr 09 16:06:35 +0000 2021
# Tweets received: 469
#     Screen name: I Stand With Tigray!!
#      Created at: Fri Apr 09 16:06:35 +0000 2021
# Tweets received: 470
#     Screen name: Rev. Mike
#      Created at: Fri Apr 09 16:06:36 +0000 2021
# Tweets received: 471
#     Screen name: 🆃🅸🅼 🅱🆈🅴🆁 i am ن
#      Created at: Fri Apr 09 16:06:36 +0000 2021
# Tweets received: 472
#     Screen name: JoK
#      Created at: Fri Apr 09 16:06:36 +0000 2021
# Tweets received: 473
#     Screen name: flpeteg
#      Created at: Fri Apr 09 16:06:36 +0000 2021
# Tweets received: 474
#     Screen name: rivz blondin
#      Created at: Fri Apr 09 16:06:37 +0000 2021
# Tweets received: 475
#     Screen name: Maite
#      Created at: Fri Apr 09 16:06:38 +0000 2021
# Tweets received: 476
#     Screen name: David Razowsky
#      Created at: Fri Apr 09 16:06:38 +0000 2021
# Tweets received: 477
#     Screen name: Peepster
#      Created at: Fri Apr 09 16:06:38 +0000 2021
# Tweets received: 478
#     Screen name: Hold them accountable 🇨🇦🇺🇸
#      Created at: Fri Apr 09 16:06:39 +0000 2021
# Tweets received: 479
#     Screen name: d kemp
#      Created at: Fri Apr 09 16:06:40 +0000 2021
# Tweets received: 480
#     Screen name: Maite
#      Created at: Fri Apr 09 16:06:41 +0000 2021
# Tweets received: 481
#     Screen name: Ari Kleit
#      Created at: Fri Apr 09 16:06:41 +0000 2021
# Tweets received: 482
#     Screen name: Let's roll...
#      Created at: Fri Apr 09 16:06:41 +0000 2021
# Tweets received: 483
#     Screen name: TWGRP 18 Susan
#      Created at: Fri Apr 09 16:06:42 +0000 2021
# Tweets received: 484
#     Screen name: Kasaraya
#      Created at: Fri Apr 09 16:06:42 +0000 2021
# Tweets received: 485
#     Screen name: Eric Banks
#      Created at: Fri Apr 09 16:06:42 +0000 2021
# Tweets received: 486
#     Screen name: Deidre 🦁🐯🦛🦉🦦🦡🦧🐿🤎
#      Created at: Fri Apr 09 16:06:43 +0000 2021
# Tweets received: 487
#     Screen name: NEVER Trump
#      Created at: Fri Apr 09 16:06:44 +0000 2021
# Tweets received: 488
#     Screen name: Maite
#      Created at: Fri Apr 09 16:06:44 +0000 2021
# Tweets received: 489
#     Screen name: JT Garcia
#      Created at: Fri Apr 09 16:06:44 +0000 2021
# Tweets received: 490
#     Screen name: Barbara B999
#      Created at: Fri Apr 09 16:06:45 +0000 2021
# Tweets received: 491
#     Screen name: Connie
#      Created at: Fri Apr 09 16:06:45 +0000 2021
# Tweets received: 492
#     Screen name: Maria de los Angeles Hernandez-Valero
#      Created at: Fri Apr 09 16:06:45 +0000 2021
# Tweets received: 493
#     Screen name: JCS
#      Created at: Fri Apr 09 16:06:45 +0000 2021
# Tweets received: 494
#     Screen name: MarthaHC in Va
#      Created at: Fri Apr 09 16:06:45 +0000 2021
# Tweets received: 495
#     Screen name: Eileen
#      Created at: Fri Apr 09 16:06:46 +0000 2021
# Tweets received: 496
#     Screen name: ✝️LENAYE HEAVEN
#      Created at: Fri Apr 09 16:06:46 +0000 2021
# Tweets received: 497
#     Screen name: Marilyn Muller
#      Created at: Fri Apr 09 16:06:46 +0000 2021
# Tweets received: 498
#     Screen name: Pollyanne Hawkes
#      Created at: Fri Apr 09 16:06:47 +0000 2021
# Tweets received: 499
#     Screen name: Dave Edwards
#      Created at: Fri Apr 09 16:06:48 +0000 2021
# Tweets received: 500

# %%
db.tweets.create_index([('$**', 'text')])
# Out:
# '$**_text'

# %% [markdown]
# ### Counting tweets for Each Senator

# %%
tweet_counts = []

# %%
for senator in senators_df.TwitterHandle:
    tweet_counts.append(db.tweets.count_documents(
    {'$text': {'$search': senator}}))

# %% [markdown]
# ### Show tweet counts for each senator

# %%
tweet_counts_df = senators_df.assign(Tweets=tweet_counts)

tweet_counts_df.sort_values(by='Tweets', ascending=False).head(10)
# Out:
#    State                Name Party    TwitterHandle   TwitterID  Tweets
# 95    WV         Joe Manchin     D   Sen_JoeManchin   234374703     304
# 62    NY       Chuck Schumer     D       SenSchumer    17494010     164
# 63    NY  Kirsten Gillibrand     D    SenGillibrand    72198806     155
# 83    TN   Marsha Blackburn      R  MarshaBlackburn   278145569     155
# 84    TX         John Cornyn     R       JohnCornyn    13218102     107
# 85    TX            Ted Cruz     R       SenTedCruz  1074480192      75
# 24    IL     Tammy Duckworth     D     SenDuckworth  1058520120      69
# 33    KY           Rand Paul     R         RandPaul   216881337      49
# 15    DE         Chris Coons     D       ChrisCoons    15324851      49
# 17    FL         Marco Rubio     R       marcorubio    15745368      47

# %% [markdown]
# ### Get the state locations for plotting markers

# %%
from geopy import OpenMapQuest
import time
from state_codes import state_codes

geo = OpenMapQuest(api_key=keys.mapquest_key)

# %%
states = tweet_counts_df.State.unique()

states.sort()

# %%
locations = []

# %%
from IPython.display import clear_output

for state in states:
    processed = False
    delay = .1 
    while not processed:
        try: 
            locations.append(geo.geocode(state_codes[state] + ', USA'))
            clear_output()  # clear cell's current output before showing next one
            print(locations[-1])  
            processed = True
        except:  # timed out, so wait before trying again
            print('OpenMapQuest service timed out. Waiting.')
            time.sleep(delay)
            delay += .1
# Out:
# Wyoming, United States of America

# %% [markdown]
# ### Grouping the tweet counts by state

# %%
tweets_counts_by_state = tweet_counts_df.groupby(
    'State', as_index=False).sum()

# %%
tweets_counts_by_state.head()
# Out:
#   State  Tweets
# 0    AK       7
# 1    AL       4
# 2    AR      13
# 3    AZ      25
# 4    CA      10

# %% [markdown]
# ### Creating the Map

# %%
import folium

# %%
usmap = folium.Map(location=[39.8283, -98.5795], 
                   zoom_start=4, detect_retina=True,
                   tiles='Stamen Toner')

# %%
choropleth = folium.Choropleth(
    geo_data='us-states.json',
    name='choropleth',
    data=tweets_counts_by_state,
    columns=['State', 'Tweets'],
    key_on='feature.id',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Tweets by State'
).add_to(usmap)

layer = folium.LayerControl().add_to(usmap)

# %%
sorted_df = tweet_counts_df.sort_values(by='Tweets', ascending=False)

for index, (name, group) in enumerate(sorted_df.groupby('State')):
    strings = [state_codes[name]]  # used to assemble popup text

    for s in group.itertuples():
        strings.append(f'{s.Name} ({s.Party}); Tweets: {s.Tweets}')
        
    text = '<br>'.join(strings)  
    popup = folium.Popup(text, max_width=200)
    marker = folium.Marker(
        (locations[index].latitude, locations[index].longitude), 
        popup=popup)
    marker.add_to(usmap)

# %% [markdown]
# ### Saving and Displaying the Map

# %%
usmap.save('SenatorsTweets.html')

# %%
from IPython.display import IFrame
IFrame(src='./SenatorsTweets.html', width=800, height=450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="./SenatorsTweets.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
