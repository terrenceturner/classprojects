# %% [markdown]
# # Tweet Location Map 🗺
# The purpose of this project is to generate a Tweet locations map (i.e. tweet_map.html) after Tweets being geocoded/mapped.

# %%
import tweepy
import keys

auth = tweepy.OAuthHandler(keys.consumer_key,
                          keys.consumer_secret)

auth.set_access_token(keys.access_token,
                     keys.access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True,
                wait_on_rate_limit_notify=True)

# %%
from tweetlistener import TweetListener

tweet_listener = TweetListener(api)

# %%
tweet_stream = tweepy.Stream(auth=api.auth,
                            listener=tweet_listener)

tweet_stream.filter(track=['Mars Rover'], is_async=True)
# Out:
# Connection successful

# %%
import preprocessor as p
import sys
from textblob import TextBlob
# Out:
# Screen name: thundfh:
#    Language: en
#      Status: [1/3] ESA's ExoMars Rover will land in Oxia Planum on Mars. The site was chosen, because of evidence for sustained… https://t.co/tgEkC6SVIU

# %%
from tweetutilities import get_API

#Get API object
api = get_API()

# %%
tweets = []

counts = {'total_tweets': 0, 'locations': 0}

# %%
# Creating the locationlistener
from locationlistener import LocationListener

location_listener = LocationListener(api, counts_dict=counts,
                                    tweets_list=tweets, topic='college basketball', limit=50)

# %%
import tweepy

stream = tweepy.Stream(auth=api.auth, listener=location_listener)

stream.filter(track=['college basketball'], languages=['en'], is_async=False)
# Out:
# ggiombarrese: Very proud of my first-ever Top 10 in The Jerome, the nation's premier college basketball selection contest. Can't… https://t.co/g4DMx7PrkW
#
# JimDonaldsonJr: @buonocore_peter @BillKoch25 @PCFriarsmbb It's a revolving door now in college basketball. Kids transfer out, kids transfer in.
#
# dre1mm: I can only name 1 college basketball player Lol
#
# RSMITHWA: @bcondotta Did Hudson play college basketball? Is he a converted tight end or defensive lineman? If not, the Hawks probably won’t like him.
#
# VintageAnchor: .@nytimes bestselling author @JFeinsteinBooks returns to his first love—college basketball—with a fascinating journ… https://t.co/5MZgsCNN0U
#
# SoccerInsider: College basketball news: George Mason has fired Dave Paulsen after 6 seasons &amp; 95-91 record. Four winning campaigns… https://t.co/04BMUy0kum
#
# Magic_Max98: Time to find some college basketball winners.
#
# (I forgot how to do “B” Bubble letter) https://t.co/uWS9fGVJoe
#
# ctroberts25: @marchmadness @BoilerBall Best arena in college basketball!
#
# GBDudes: The 3-2 Zone (A College Basketball Podcast) : March Madness Extravaganza; Part 1 #CBB #MarchMadness #SEC #Big12… https://t.co/DZaM0oQAAg
#
# Birdbrains_Pod: The 3-2 Zone (A College Basketball Podcast) : March Madness Extravaganza; Part 1 #CBB #MarchMadness #SEC #Big12… https://t.co/61brNL2Ha9
#
# KY_MEDTCH: @TruUKFan I’ve watched less college basketball this year than any year that I can remember. I’m willing to bet that… https://t.co/SHUMFABnuR
#
# warneagle: I don't think I watched a non-Auburn college basketball game this year (and only watched maybe a third of Auburn's)… https://t.co/vqytXKhuZT
#
# Holmes_y_Rails: Today in College basketball discourse...
#
# The national media: The expectations around IU and their fans' extreme ov… https://t.co/lOBkRsgwO6
#
# MadisonSiriusXM: On this day in 1948, college basketball coach C. Vivian Stringer was born in Pennsylvania. She is one of the greate… https://t.co/GuRIfdY5fI
#
# brerobinsonnn: @HustlersOnlyllc I don’t pay attention to college basketball 😂😂😂😂
#
# venkatinthehat: way too into college basketball and obsessed with manspaining bf, entered an office bracket pool because it would be "fun" gf
#
# NunesMagician: Links: What college basketball is saying about Syracuse in the NCAA Tournament https://t.co/4d774OoCWG
#
# BenStandig: College basketball tweet: George Mason has fired men's basketball coach Dave Paulsen, per sources. Paulsen went 95-… https://t.co/whTt28Lj6q
#
# washingtonpost: NCAA tournament bracket picks from college basketball’s top experts https://t.co/SZihiYfHqx
#
# clubtrillion: @JonRothstein College basketball. Where the unexpected becomes the ordinary. Unless it's believing a guy might be w… https://t.co/FqIk36AFLF

# %%
counts['total_tweets']
# Out:
# 68

# %%
counts['locations']
# Out:
# 50

# %%
print(f'{counts["locations"] / counts["total_tweets"]:.1%}')
# Out:
# 73.5%

# %%
from tweetutilities import get_geocodes

bad_locations = get_geocodes(tweets)
# Out:
# Getting coordinates for tweet locations...
# Done geocoding

# %%
bad_locations
# Out:
# 8

# %%
print(f'{bad_locations / counts["locations"]:.1%}')
# Out:
# 16.0%

# %%
import pandas as pd

#Create DataFrame
df = pd.DataFrame(tweets)

#Drop Null Values
df = df.dropna()

# %%
#Creating a Map with Folium
import folium

usmap = folium.Map(location=[39.8283, -98.5795], 
                   tiles='Stamen Terrain',
                   zoom_start=5, detect_retina=True)

# %%
#Creating Popup Markers for the Tweet Locations
for t in df.itertuples():
    text = ': '.join([t.screen_name, t.text])
    popup = folium.Popup(text, parse_html=True) 
    marker = folium.Marker((t.latitude, t.longitude),
                           popup=popup)
    marker.add_to(usmap)

# %%
df.head()
# Out:
#       screen_name                                               text  \
# 0  dododoiscoolnc  @Illicit_Nature no it's the college basketball...
# 1     Hoosiers530  @AssemblyCall @JayBilas -Most college basketba...
# 2         IUBBGuy  How to get attention as a college basketball a...
# 3       royallote         Best program in college basketball history
# 4    STNSportsApp  🎙NEW PODCAST🎙\n\nMarch is here, and that means...
#
#         location   latitude   longitude
# 0    raleigh, nc  35.780398  -78.639099
# 1  Fort Wayne,IN  41.079990  -85.138601
# 2       Indiana   40.327013  -86.174693
# 3  Charlotte, NC  35.227087  -80.843127
# 4      Las Vegas  36.166286 -115.149225

# %%
usmap.save('tweet_map.html')

# %%
from IPython.display import HTML

HTML('tweet_map.html')
# Out:
# <!DOCTYPE html>
# <head>
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css"/>
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_570dc3b9716149f8b2b811c5118fc866 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
# </head>
# <body>
#
#             <div class="folium-map" id="map_570dc3b9716149f8b2b811c5118fc866" ></div>
#
# </body>
# <script>
#
#             var map_570dc3b9716149f8b2b811c5118fc866 = L.map(
#                 "map_570dc3b9716149f8b2b811c5118fc866",
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     detectRetina: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e8c760acc6043fd9f7ccaf9a5e26d2c = L.tileLayer(
#                 "https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg",
#                 {"attribution": "Map tiles by \u003ca href=\"http://stamen.com\"\u003eStamen Design\u003c/a\u003e, under \u003ca href=\"http://creativecommons.org/licenses/by/3.0\"\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\"http://openstreetmap.org\"\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\"http://creativecommons.org/licenses/by-sa/3.0\"\u003eCC BY SA\u003c/a\u003e.", "detectRetina": false, "maxNativeZoom": 18, "maxZoom": 18, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abc", "tms": false}
#             ).addTo(map_570dc3b9716149f8b2b811c5118fc866);
#
#
#             var marker_52dff517e6eb4c6190da45c7d582ed3c = L.marker(
#                 [35.7803977, -78.6390989],
#                 {}
#             ).addTo(map_570dc3b9716149f8b2b811c5118fc866);
#
#
#         var popup_d2febcbb869c4a3ab5ccba26e361cea7 = L.popup({"maxWidth": "100%"});
#
#
#             var html_3fb69a131e814f3fb14789c20c20fa24 = $(`<div id="html_3fb69a131e814f3fb14789c20c20fa24" style="width: 100.0%; height: 100.0%;">dododoiscoolnc: @Illicit_Nature no it&#39;s the college basketball tournament in March lmao</div>`)[0];
#             popup_d2febcbb869c4a3ab5ccba26e361cea7.setContent(html_3fb69a131e814f3fb14789c20c20fa24);
#
#
#         marker_52dff517e6eb4c6190da45c7d582ed3c.bindPopup(popup_d2febcbb869c4a3ab5ccba26e361cea7)
#         ;
#
#
#
#
#             var marker_03ed2c86fede41feab06ec451df41da9 = L.marker(
#                 [41.0799898, -85.1386015],
#                 {}
#             ).addTo(map_570dc3b9716149f8b2b811c5118fc866);
#
#
#         var popup_85a0d775ca484864a7abcdd5efabf58b = L.popup({"maxWidth": "100%"});
#
#
#             var html_84c2e6fcd55241cfa71ef9d77677bb17 = $(`<div id="html_84c2e6fcd55241cfa71ef9d77677bb17" style="width: 100.0%; height: 100.0%;">Hoosiers530: @AssemblyCall @JayBilas -Most college basketball pundits last week: Yeah archie is just not working i dont know wha… https://t.co/0dX7gywEXO</div>`)[0];
#             popup_85a0d775ca484864a7abcdd5efabf58b.setContent(html_84c2e6fcd55241cfa71ef9d77677bb17);
#
#
#         marker_03ed2c86fede41feab06ec451df41da9.bindPopup(popup_85a0d775ca484864a7abcdd5efabf58b)
#         ;
#
#
#
#
#             var marker_3a8bedcc9bfe41f598909694e5a950b6 = L.marker(
#                 [40.3270127, -86.1746933],
#                 {}
#             ).addTo(map_570dc3b9716149f8b2b811c5118fc866);
#
#
#         var popup_b32edbdd820f4de38533e2bbacb0ac17 = L.popup({"maxWidth": "100%"});
#
#
#             var html_bbf58a101b594848b8f1fcd757dfb579 = $(`<div id="html_bbf58a101b594848b8f1fcd757dfb579" style="width: 100.0%; height: 100.0%;">IUBBGuy: How to get attention as a college basketball analyst ⬇️  Say something about #iubb and/or their fan base</div>`)[0];
#             popup_b32edbdd820f4de38533e2bbacb0ac17.setContent(html_bbf58a101b594848b8f1fcd757dfb579);
#
#
#         marker_3a8bedcc9bfe41f598909694e5a950b6.bindPopup(popup_b32edbdd820f4de38533e2bbacb0ac17)
#         ;
#
#
#
#
#             var marker_dba5d0a891ff4350ac4996bc1a0835e3 = L.marker(
#                 [35.2270869, -80.8431268],
#                 {}
#             ).addTo(map_570dc3b9716149f8b2b811c5118fc866);
#
#
#         var popup_a3cc4c4a771a4de99efda260e1dd778b = L.popup({"maxWidth": "100%"});
#
#
#             var html_ae4fb0a317cb4164b4d932ba53f46219 = $(`<div id="html_ae4fb0a317cb4164b4d932ba53f46219" style="width: 100.0%; height: 100.0%;">royallote: Best program in college basketball history</div>`)[0];
#             popup_a3cc4c4a771a4de99efda260e1dd778b.setContent(html_ae4fb0a317cb4164b4d932ba53f46219);
#
#
#         marker_dba5d0a891ff4350ac4996bc1a0835e3.bindPopup(popup_a3cc4c4a771a4de99efda260e1dd778b)
#         ;
#
#
#
#
#             var marker_888afb4379f949f4b9ede4b1f85d8154 = L.marker(
#                 [36.1662859, -115.149225],
#                 {}
#             ).addTo(map_570dc3b9716149f8b2b811c5118fc866);
#
#
#         var popup_36dafa471e6d4793a4a5bf4a8424cff7 = L.popup({"maxWidth": "100%"});
#
#
#             var html_6ff651b40cf748ef9c027ac079b26389 = $(`<div id="html_6ff651b40cf748ef9c027ac079b26389" style="width: 100.0%; height: 100.0%;">STNSportsApp: 🎙NEW PODCAST🎙  March is here, and that means college basketball.  Here&#39;s everything happening at Station Casinos fo… https://t.co/0ak0DXOe4y</div>`)[0];
#             popup_36dafa471e6d4793a4a5bf4a8424cff7.setContent(html_6ff651b40cf748ef9c027ac079b26389);
#
#
#         marker_888afb4379f949f4b9ede4b1f85d8154.bindPopup(popup_36dafa471e6d4793a4a5bf4a8424cff7)
#         ;
#
#
#
#
#             var marker_bc3e17503dc3460193b1bcf1b4e0dd38 = L.marker(
#                 [38.265121, -85.723562],
#                 {}
#             ).addTo(map_570dc3b9716149f8b2b811c5118fc866);
#
#
#         var popup_5f49ee3faf254029a3ad1f0a5c120bda = L.popup({"maxWidth": "100%"});
#
#
#             var html_be00c245c5f7407dbc437e0beea87a6a = $(`<div id="html_be00c245c5f7407dbc437e0beea87a6a" style="width: 100.0%; height: 100.0%;">jeb_center: Gabby Decamillis dreams of becoming a college basketball player one day and moving to Hawaii to sell smoothies out… https://t.co/qnKYsYdOUk</div>`)[0];
#             popup_5f49ee3faf254029a3ad1f0a5c120bda.setContent(html_be00c245c5f7407dbc437e0beea87a6a)
